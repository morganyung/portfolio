# %%
# !pip install keybert
# !pip install transformers
# !pip install bertopic
# !pip install -q transformers einops accelerate langchain bitsandbytes
# !pip install trl
# !pip install xformers

# %%
#!pip install bertopic

# %%
from langchain import HuggingFacePipeline
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline, AutoModel, AutoModelForSequenceClassification
import torch
import torch.nn.functional as F
from datasets import load_dataset
from bertopic import BERTopic
from sklearn.feature_extraction.text import CountVectorizer
from bertopic.vectorizers import ClassTfidfTransformer
from bertopic.representation import KeyBERTInspired
from bertopic.representation import PartOfSpeech
from bertopic.representation import MaximalMarginalRelevance
import spacy
import gensim
import pandas as pd
import numpy as np
from bertopic.representation import ZeroShotClassification
from bertopic.representation import TextGeneration
import en_core_web_sm
import nltk
nltk.download('punkt')
from nltk.tokenize import sent_tokenize
# Out:
# [nltk_data] Downloading package punkt to /home/ec2-user/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
df = pd.read_csv('labeled_final.csv')

# %%
# !pip install hdbscan
# !sudo yum install -y gcc
# !pip install hdbscan
#!python -m spacy download en_core_web_sm

# %%
df.head()
# Out:
#    index product  overall  vote  verified   reviewTime      reviewerID  \
# 0      0  ladder        1   NaN      True  08 12, 2015  A1L1U5H7ZVOBBE
# 1      1  ladder        1   NaN      True  10 19, 2016  A2T4TNHPL68SYK
# 2      2  ladder        3   NaN      True  10 30, 2004   A6SHOGP56RZLA
# 3      3  ladder        1  23.0      True   12 1, 2005  A2971BCXW8MCKY
# 4      4  ladder        3   2.0      True   03 4, 2011  A3HI1K6M2SPB1H
#
#          asin                       style      reviewerName  ...  \
# 0  B0000224LY  {'Size Name:': ' 28 Feet'}  Andreas Ringstad  ...
# 1  B0000224LY  {'Size Name:': ' 32 Feet'}   Amazon Customer  ...
# 2  B0000224M4   {'Size Name:': ' 2 Feet'}   Jeffrey S. Alek  ...
# 3  B0000224LQ                         NaN          M. Lewis  ...
# 4  B0000224LQ                         NaN     Rena K. Rouse  ...
#
#                    main_cat  \
# 0  Tools & Home Improvement
# 1  Tools & Home Improvement
# 2  Tools & Home Improvement
# 3  Tools & Home Improvement
# 4  Tools & Home Improvement
#
#                                         similar_item              date  \
# 0   class="a-bordered a-horizontal-stripes  a-spa...  November 8, 1999
# 1   class="a-bordered a-horizontal-stripes  a-spa...  November 8, 1999
# 2   class="a-bordered a-horizontal-stripes  a-spa...  November 8, 1999
# 3   class="a-bordered a-horizontal-stripes  a-spa...  November 8, 1999
# 4   class="a-bordered a-horizontal-stripes  a-spa...  November 8, 1999
#
#      price                                           imageURL  \
# 0  $291.23                                                 []
# 1  $291.23                                                 []
# 2      NaN                                                 []
# 3      NaN  ['https://images-na.ssl-images-amazon.com/imag...
# 4      NaN  ['https://images-na.ssl-images-amazon.com/imag...
#
#                                      imageURLHighRes details  \
# 0                                                 []      {}
# 1                                                 []      {}
# 2                                                 []      {}
# 3  ['https://images-na.ssl-images-amazon.com/imag...      {}
# 4  ['https://images-na.ssl-images-amazon.com/imag...      {}
#
#              reviewType mostReviewed_rank avg_star_rating
# 0   Delivery/ Packaging              47.0             1.0
# 1   Delivery/ Packaging              47.0             1.0
# 2  Design/Functionality              48.0             3.0
# 3               Quality              47.0             2.0
# 4  Design/Functionality              47.0             2.0
#
# [5 rows x 35 columns]

# %%
df_simple = df[['product', 'reviewText', 'reviewType']]

# %%
df_simple.head()
# Out:
#   product                                         reviewText  \
# 0  ladder            Arrived with a defective lock assembly.
# 1  ladder  The ladder quality was very good but trying to...
# 2  ladder  Used mine for the first time today.  Very happ...
# 3  ladder  This is not the original telesteps made in Swe...
# 4  ladder  I was excited about this product at first, but...
#
#              reviewType
# 0   Delivery/ Packaging
# 1   Delivery/ Packaging
# 2  Design/Functionality
# 3               Quality
# 4  Design/Functionality

# %%
#df_sub = df_simple[(df_simple['product'] == 'mower') & (df_simple['reviewType'] == 'Quality')]

# %%
#df_sub.head()
# Out:
#      product                                         reviewText reviewType
# 2933   mower  Ordered and paid for the 1815-18 18 Inch 5 Bla...    Quality
# 2938   mower  Was great while it lasted. Handle broke off an...    Quality
# 2946   mower  The item arrived without the handle rods. So b...    Quality
# 2952   mower  Broke within a couple month of use and really ...    Quality
# 2960   mower  Item was flimsy and did not cut grass.  The de...    Quality

# %%
representation_model = [KeyBERTInspired(top_n_words=30), MaximalMarginalRelevance(diversity=.3)]
topic_model = BERTopic(representation_model=representation_model)

# %%
def topic_token(data, by_sent):
    #by_sent is a boolean
    reviews = [str(review) for review in data['reviewText']]
    if by_sent: 
        reviews_bySent = [sent_tokenize(r) for r in reviews]
        reviews_sent = []
        for item in reviews_bySent:
            if len(item) == 1:
                reviews_sent.append(item[0])
            else:
                for i in item:
                    reviews_sent.append(i)
        return reviews_sent
    else:
        return reviews

# %%
def get_topic_df(df_sub, topic_num, product, reviewType):
    sample_sent = topic_token(df_sub, True)
    topics, probs = topic_model.fit_transform(sample_sent)
    rep_doc = topic_model.get_representative_docs(topic= topic_num)[0]
    df1 = pd.DataFrame(topic_model.get_topic(topic_num), columns=['keyword', 'relevance_score']).sort_values(by = 'relevance_score', ascending = False).head(5)
    freq = topic_model.get_topic_freq(topic = topic_num)
    df1['rep_doc'] = rep_doc
    df1['freq'] = freq
    df1['topic_index'] = topic_num
    df1['product'] = product
    df1['reviewType'] = reviewType
    return df1

# %%
prod_list = df_simple['product'].unique()
review_list = df_simple['reviewType'].unique()

# %%
from tqdm import tqdm
total_iterations = len(prod_list) * len(review_list) * 3

# %%
progress_bar = tqdm(total=total_iterations, desc='Processing')

joined_df = pd.DataFrame()
for product in prod_list:
    for reviewType in review_list:
        df_sub = df_simple[(df_simple['product'] == product) & (df_simple['reviewType'] == reviewType)]
        for topic_num in range(3):
            df2 = get_topic_df(df_sub, topic_num, product, reviewType)
            joined_df = pd.concat([joined_df, df2])
            progress_bar.update(1)
progress_bar.close()
# Out:
# Processing:  33%|█████████▋                   | 12/36 [03:12<05:09, 12.90s/it]
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Processing: 100%|█████████████████████████████| 36/36 [15:11<00:00, 25.33s/it]

# %%
joined_df
# Out:
#      keyword  relevance_score                                        rep_doc  \
# 0     ladder         0.781868        Ladder looks like it was a used ladder.
# 1    ladders         0.720694        Ladder looks like it was a used ladder.
# 2       step         0.328507        Ladder looks like it was a used ladder.
# 3     sturdy         0.294912        Ladder looks like it was a used ladder.
# 4    plastic         0.191308        Ladder looks like it was a used ladder.
# ..       ...              ...                                            ...
# 0   keyboard         0.563985  It has a drawer instead of the keyboard tray.
# 1       tray         0.550895  It has a drawer instead of the keyboard tray.
# 2     drawer         0.416834  It has a drawer instead of the keyboard tray.
# 3      mouse         0.252429  It has a drawer instead of the keyboard tray.
# 4     screws         0.173733  It has a drawer instead of the keyboard tray.
#
#     freq  topic_index product           reviewType
# 0    552            0  ladder  Delivery/ Packaging
# 1    552            0  ladder  Delivery/ Packaging
# 2    552            0  ladder  Delivery/ Packaging
# 3    552            0  ladder  Delivery/ Packaging
# 4    552            0  ladder  Delivery/ Packaging
# ..   ...          ...     ...                  ...
# 0    102            2    desk              Quality
# 1    102            2    desk              Quality
# 2    102            2    desk              Quality
# 3    102            2    desk              Quality
# 4    102            2    desk              Quality
#
# [180 rows x 7 columns]

# %%
joined_df.to_excel("topics_final.xlsx", index=False)

# %%
#df_sub = df_simple[(df_simple['product'] == 'mower') & (df_simple['reviewType'] == 'Quality')]

# %%
get_topic_df(df_sub, topic_num, product, reviewType)
# Out:
#      keyword  relevance_score                          rep_doc  freq  \
# 0   charging         0.534170  Battery would not fully charge.  1275
# 1   recharge         0.444163  Battery would not fully charge.  1275
# 2  batteries         0.438387  Battery would not fully charge.  1275
# 3    charger         0.435587  Battery would not fully charge.  1275
# 4    plugged         0.398141  Battery would not fully charge.  1275
#
#    topic_index product reviewType
# 0            0   mower    Quality
# 1            0   mower    Quality
# 2            0   mower    Quality
# 3            0   mower    Quality
# 4            0   mower    Quality

# %%
#sample_sent = topic_token(df_sub, True)

# %%
# topics, probs = topic_model.fit_transform(sample_sent)
# topic_model.get_topic_info()
# Out:
#      Topic  Count                                         Name  \
# 0       -1   4680                     -1_mower_mowing_lawn_mow
# 1        0   1290        0_charging_recharge_charger_batteries
# 2        1    541             1_lawnmower_mowing_lawn_charging
# 3        2    491                   2_wheel_broke_axles_broken
# 4        3    251              3_starts_start_starting_startup
# ..     ...    ...                                          ...
# 229    228     10      228_quality_control_manufacturer_issues
# 230    229     10             229_lawn_jammed_lifespan_cutting
# 231    230     10            230_locally_walmart_purchase_shop
# 232    231     10            231_mower_lawnmower_cordless_lawn
# 233    232     10  232_transmission_repaired_mechanic_warranty
#
#                                         Representation  \
# 0    [mower, mowing, lawn, mow, worked, working, st...
# 1    [charging, recharge, charger, batteries, plugg...
# 2    [lawnmower, mowing, lawn, charging, batteries,...
# 3    [wheel, broke, axles, broken, dropped, steerin...
# 4    [starts, start, starting, startup, restart, ca...
# ..                                                 ...
# 229  [quality, control, manufacturer, issues, dept,...
# 230  [lawn, jammed, lifespan, cutting, plowed, trim...
# 231  [locally, walmart, purchase, shop, store, shop...
# 232  [mower, lawnmower, cordless, lawn, cord, corde...
# 233  [transmission, repaired, mechanic, warranty, c...
#
#                                    Representative_Docs
# 0    [While it was working, it was nice and quiet, ...
# 1    [Fully charged battery (took 5 hours to turn r...
# 2    [After fully charging I cut my front lawn with...
# 3    [Then the front left wheel came off., The righ...
# 4    [Will not start now., It will not start., Wont...
# ..                                                 ...
# 229  [Very poor quality control., Quality control i...
# 230  [It gets jammed on almost every stick in the y...
# 231  [Buy from a local store., I will purchase loca...
# 232  [I will still likely stick with a corded elect...
# 233  [Addendum as of 7/25/2018  The transmission bl...
#
# [234 rows x 5 columns]

# %%
# topic_num = 0
# rep_doc = topic_model.get_representative_docs(topic= topic_num)[0]
